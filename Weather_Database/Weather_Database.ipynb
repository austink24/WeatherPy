# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# upacking to Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
coordinates



# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#create empty list to hold our city data
city_data = []


# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# city = 'Boston'
# city_url = url + "&q=" + city.replace(" ","+")
# city_url

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Country": city_country,
                      "Current Description": city_description})                  
    except:
        print('City not Found')
# Out:
# Processing Record 1 of Set 1 | souillac
# Processing Record 2 of Set 1 | kovur
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | pisco
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | luohe
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | talnakh
# Processing Record 14 of Set 1 | ponta do sol
# Processing Record 15 of Set 1 | faanui
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | sibiti
# Processing Record 18 of Set 1 | mount isa
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | nanortalik
# Processing Record 21 of Set 1 | flinders
# Processing Record 22 of Set 1 | santa maria
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | gorontalo
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | yaan
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | inirida
# Processing Record 29 of Set 1 | omboue
# Processing Record 30 of Set 1 | cockburn harbour
# City not Found
# Processing Record 31 of Set 1 | vao
# Processing Record 32 of Set 1 | vestmannaeyjar
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | danane
# Processing Record 35 of Set 1 | belushya guba
# City not Found
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | tual
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | attawapiskat
# City not Found
# Processing Record 41 of Set 1 | salalah
# Processing Record 42 of Set 1 | punta gorda
# Processing Record 43 of Set 1 | kruisfontein
# Processing Record 44 of Set 1 | saskylakh
# Processing Record 45 of Set 1 | leningradskiy
# Processing Record 46 of Set 1 | toliary
# City not Found
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | dzhusaly
# City not Found
# Processing Record 49 of Set 1 | grand river south east
# City not Found
# Processing Record 50 of Set 1 | cherskiy
# Processing Record 1 of Set 2 | kavaratti
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | ahipara
# Processing Record 4 of Set 2 | mys shmidta
# City not Found
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not Found
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | nampula
# Processing Record 8 of Set 2 | kabo
# Processing Record 9 of Set 2 | hami
# Processing Record 10 of Set 2 | taolanaro
# City not Found
# Processing Record 11 of Set 2 | puerto palomas
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | atar
# Processing Record 14 of Set 2 | airai
# Processing Record 15 of Set 2 | naryan-mar
# Processing Record 16 of Set 2 | yumen
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | lagoa
# Processing Record 20 of Set 2 | gzhatsk
# City not Found
# Processing Record 21 of Set 2 | kawalu
# Processing Record 22 of Set 2 | ngukurr
# City not Found
# Processing Record 23 of Set 2 | zaozerne
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | dunlop
# Processing Record 26 of Set 2 | samusu
# City not Found
# Processing Record 27 of Set 2 | khonuu
# City not Found
# Processing Record 28 of Set 2 | donegal
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | bluff
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | tura
# Processing Record 33 of Set 2 | mataura
# Processing Record 34 of Set 2 | bambous virieux
# Processing Record 35 of Set 2 | labuan
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | jahrom
# City not Found
# Processing Record 38 of Set 2 | pauini
# Processing Record 39 of Set 2 | tallahassee
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | barentsburg
# City not Found
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | nizhneyansk
# City not Found
# Processing Record 46 of Set 2 | harbin
# Processing Record 47 of Set 2 | kuliyapitiya
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | cabo san lucas
# Processing Record 50 of Set 2 | hermanus
# Processing Record 1 of Set 3 | necochea
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | mandera
# Processing Record 4 of Set 3 | bud
# Processing Record 5 of Set 3 | mount gambier
# Processing Record 6 of Set 3 | sao joao da barra
# Processing Record 7 of Set 3 | egvekinot
# Processing Record 8 of Set 3 | chapais
# Processing Record 9 of Set 3 | neiafu
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | saint-nazaire
# Processing Record 12 of Set 3 | grand gaube
# Processing Record 13 of Set 3 | nardaran
# Processing Record 14 of Set 3 | komsomolskiy
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | tarakan
# Processing Record 17 of Set 3 | lieto
# Processing Record 18 of Set 3 | sibolga
# Processing Record 19 of Set 3 | carnarvon
# Processing Record 20 of Set 3 | haibowan
# City not Found
# Processing Record 21 of Set 3 | albany
# Processing Record 22 of Set 3 | poya
# Processing Record 23 of Set 3 | kaitangata
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | kasamwa
# Processing Record 26 of Set 3 | chicama
# Processing Record 27 of Set 3 | hambantota
# Processing Record 28 of Set 3 | khorixas
# Processing Record 29 of Set 3 | dolores
# Processing Record 30 of Set 3 | makakilo city
# Processing Record 31 of Set 3 | moerai
# Processing Record 32 of Set 3 | wendo
# Processing Record 33 of Set 3 | iqaluit
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | aripuana
# Processing Record 36 of Set 3 | saint-augustin
# Processing Record 37 of Set 3 | tuatapere
# Processing Record 38 of Set 3 | luba
# Processing Record 39 of Set 3 | narsaq
# Processing Record 40 of Set 3 | beringovskiy
# Processing Record 41 of Set 3 | westport
# Processing Record 42 of Set 3 | sumbawa
# City not Found
# Processing Record 43 of Set 3 | sfantu gheorghe
# Processing Record 44 of Set 3 | coihaique
# Processing Record 45 of Set 3 | wilmington
# Processing Record 46 of Set 3 | severo-kurilsk
# Processing Record 47 of Set 3 | ballina
# Processing Record 48 of Set 3 | rio cuarto
# Processing Record 49 of Set 3 | yueyang
# Processing Record 50 of Set 3 | ola
# Processing Record 1 of Set 4 | puerto del rosario
# Processing Record 2 of Set 4 | haines junction
# Processing Record 3 of Set 4 | port blair
# Processing Record 4 of Set 4 | imbituba
# Processing Record 5 of Set 4 | aloleng
# Processing Record 6 of Set 4 | cap malheureux
# Processing Record 7 of Set 4 | sinkat
# City not Found
# Processing Record 8 of Set 4 | tolaga bay
# Processing Record 9 of Set 4 | nsoko
# Processing Record 10 of Set 4 | arlit
# Processing Record 11 of Set 4 | mar del plata
# Processing Record 12 of Set 4 | yulara
# Processing Record 13 of Set 4 | brae
# Processing Record 14 of Set 4 | san jose
# Processing Record 15 of Set 4 | labuhan
# Processing Record 16 of Set 4 | barrow
# Processing Record 17 of Set 4 | longyearbyen
# Processing Record 18 of Set 4 | burnie
# Processing Record 19 of Set 4 | pangnirtung
# Processing Record 20 of Set 4 | puerto ayora
# Processing Record 21 of Set 4 | tuktoyaktuk
# Processing Record 22 of Set 4 | bairiki
# Processing Record 23 of Set 4 | deputatskiy
# Processing Record 24 of Set 4 | alofi
# Processing Record 25 of Set 4 | sakata
# Processing Record 26 of Set 4 | cheuskiny
# City not Found
# Processing Record 27 of Set 4 | granadilla de abona
# Processing Record 28 of Set 4 | ponta delgada
# Processing Record 29 of Set 4 | niimi
# Processing Record 30 of Set 4 | isangel
# Processing Record 31 of Set 4 | pevek
# Processing Record 32 of Set 4 | prabumulih
# Processing Record 33 of Set 4 | coahuayana
# Processing Record 34 of Set 4 | muncar
# Processing Record 35 of Set 4 | frunze
# Processing Record 36 of Set 4 | tumannyy
# City not Found
# Processing Record 37 of Set 4 | san cristobal
# Processing Record 38 of Set 4 | pemangkat
# Processing Record 39 of Set 4 | saint george
# Processing Record 40 of Set 4 | jalu
# Processing Record 41 of Set 4 | vila velha
# Processing Record 42 of Set 4 | adrar
# Processing Record 43 of Set 4 | kirakira
# Processing Record 44 of Set 4 | derzhavinsk
# Processing Record 45 of Set 4 | xining
# Processing Record 46 of Set 4 | galveston
# Processing Record 47 of Set 4 | shahreza
# Processing Record 48 of Set 4 | minot
# Processing Record 49 of Set 4 | turukhansk
# Processing Record 50 of Set 4 | aklavik
# Processing Record 1 of Set 5 | fortuna
# Processing Record 2 of Set 5 | lompoc
# Processing Record 3 of Set 5 | gardan diwal
# City not Found
# Processing Record 4 of Set 5 | saint anthony
# Processing Record 5 of Set 5 | churapcha
# Processing Record 6 of Set 5 | tessalit
# Processing Record 7 of Set 5 | chengalpattu
# Processing Record 8 of Set 5 | verkh-suetka
# Processing Record 9 of Set 5 | verdun
# Processing Record 10 of Set 5 | saint-philippe
# Processing Record 11 of Set 5 | sao felix do xingu
# Processing Record 12 of Set 5 | sentyabrskiy
# City not Found
# Processing Record 13 of Set 5 | constitucion
# Processing Record 14 of Set 5 | causapscal
# Processing Record 15 of Set 5 | am timan
# Processing Record 16 of Set 5 | port antonio
# Processing Record 17 of Set 5 | itarema
# Processing Record 18 of Set 5 | baykit
# Processing Record 19 of Set 5 | codrington
# Processing Record 20 of Set 5 | thunder bay
# Processing Record 21 of Set 5 | sept-iles
# Processing Record 22 of Set 5 | krasnaya gorbatka
# Processing Record 23 of Set 5 | tiznit
# Processing Record 24 of Set 5 | vostok
# Processing Record 25 of Set 5 | umzimvubu
# City not Found
# Processing Record 26 of Set 5 | burica
# City not Found
# Processing Record 27 of Set 5 | mollendo
# Processing Record 28 of Set 5 | asyut
# Processing Record 29 of Set 5 | norman wells
# Processing Record 30 of Set 5 | marawi
# Processing Record 31 of Set 5 | kysyl-syr
# Processing Record 32 of Set 5 | saldanha
# Processing Record 33 of Set 5 | caravelas
# Processing Record 34 of Set 5 | sisimiut
# Processing Record 35 of Set 5 | umm kaddadah
# Processing Record 36 of Set 5 | sindor
# Processing Record 37 of Set 5 | ust-nera
# Processing Record 38 of Set 5 | alyangula
# Processing Record 39 of Set 5 | esperance
# Processing Record 40 of Set 5 | erzin
# Processing Record 41 of Set 5 | zhigansk
# Processing Record 42 of Set 5 | hithadhoo
# Processing Record 43 of Set 5 | te anau
# Processing Record 44 of Set 5 | iskateley
# Processing Record 45 of Set 5 | severo-yeniseyskiy
# Processing Record 46 of Set 5 | dargaville
# Processing Record 47 of Set 5 | chokurdakh
# Processing Record 48 of Set 5 | lircay
# Processing Record 49 of Set 5 | puerto leguizamo
# Processing Record 50 of Set 5 | eucaliptus
# Processing Record 1 of Set 6 | kapaa
# Processing Record 2 of Set 6 | lisala
# Processing Record 3 of Set 6 | janakpur
# Processing Record 4 of Set 6 | tir pol
# City not Found
# Processing Record 5 of Set 6 | verkhnevilyuysk
# Processing Record 6 of Set 6 | strezhevoy
# Processing Record 7 of Set 6 | waingapu
# Processing Record 8 of Set 6 | luderitz
# Processing Record 9 of Set 6 | praia da vitoria
# Processing Record 10 of Set 6 | ocos
# Processing Record 11 of Set 6 | san joaquin
# Processing Record 12 of Set 6 | znamenskoye
# Processing Record 13 of Set 6 | umm lajj
# Processing Record 14 of Set 6 | ketchikan
# Processing Record 15 of Set 6 | rio bueno
# Processing Record 16 of Set 6 | katsuura
# Processing Record 17 of Set 6 | adwa
# Processing Record 18 of Set 6 | broome
# Processing Record 19 of Set 6 | hovd
# Processing Record 20 of Set 6 | comodoro rivadavia
# Processing Record 21 of Set 6 | ashland
# Processing Record 22 of Set 6 | yar-sale
# Processing Record 23 of Set 6 | college
# Processing Record 24 of Set 6 | havelock
# Processing Record 25 of Set 6 | honningsvag
# Processing Record 26 of Set 6 | fare
# Processing Record 27 of Set 6 | dinhata
# Processing Record 28 of Set 6 | kavieng
# Processing Record 29 of Set 6 | virginia beach
# Processing Record 30 of Set 6 | novobiryusinskiy
# Processing Record 31 of Set 6 | oyama
# Processing Record 32 of Set 6 | pitimbu
# Processing Record 33 of Set 6 | sapernoye
# Processing Record 34 of Set 6 | zhuanghe
# Processing Record 35 of Set 6 | hamilton
# Processing Record 36 of Set 6 | rafai
# Processing Record 37 of Set 6 | korla
# Processing Record 38 of Set 6 | hofn
# Processing Record 39 of Set 6 | udachnyy
# Processing Record 40 of Set 6 | nome
# Processing Record 41 of Set 6 | dhidhdhoo
# Processing Record 42 of Set 6 | richards bay
# Processing Record 43 of Set 6 | costinesti
# Processing Record 44 of Set 6 | whittlesea
# Processing Record 45 of Set 6 | atocha
# Processing Record 46 of Set 6 | villarrica
# Processing Record 47 of Set 6 | henties bay
# Processing Record 48 of Set 6 | hailar
# Processing Record 49 of Set 6 | mehamn
# Processing Record 50 of Set 6 | chikwawa
# Processing Record 1 of Set 7 | haverfordwest
# Processing Record 2 of Set 7 | shkotovo-26
# City not Found
# Processing Record 3 of Set 7 | sorvag
# City not Found
# Processing Record 4 of Set 7 | pombas
# Processing Record 5 of Set 7 | nemuro
# Processing Record 6 of Set 7 | vila franca do campo
# Processing Record 7 of Set 7 | touros
# Processing Record 8 of Set 7 | tsihombe
# City not Found
# Processing Record 9 of Set 7 | sola
# Processing Record 10 of Set 7 | vardo
# Processing Record 11 of Set 7 | nantucket
# Processing Record 12 of Set 7 | leh
# Processing Record 13 of Set 7 | cortez
# Processing Record 14 of Set 7 | garden city
# Processing Record 15 of Set 7 | saint pete beach
# Processing Record 16 of Set 7 | warrington
# Processing Record 17 of Set 7 | murygino
# Processing Record 18 of Set 7 | nicolas bravo
# Processing Record 19 of Set 7 | yushu
# Processing Record 20 of Set 7 | yeppoon
# Processing Record 21 of Set 7 | zaria
# Processing Record 22 of Set 7 | anadyr
# Processing Record 23 of Set 7 | saint-joseph
# Processing Record 24 of Set 7 | ixtapa
# Processing Record 25 of Set 7 | balad
# Processing Record 26 of Set 7 | tateyama
# Processing Record 27 of Set 7 | sur
# Processing Record 28 of Set 7 | shakawe
# Processing Record 29 of Set 7 | taketa
# Processing Record 30 of Set 7 | markala
# Processing Record 31 of Set 7 | presidencia roque saenz pena
# Processing Record 32 of Set 7 | inhambane
# Processing Record 33 of Set 7 | seljord
# Processing Record 34 of Set 7 | buin
# Processing Record 35 of Set 7 | torbay
# Processing Record 36 of Set 7 | port lincoln
# Processing Record 37 of Set 7 | mahibadhoo
# Processing Record 38 of Set 7 | warwick
# Processing Record 39 of Set 7 | axim
# Processing Record 40 of Set 7 | warmbad
# Processing Record 41 of Set 7 | ancud
# Processing Record 42 of Set 7 | karatau
# Processing Record 43 of Set 7 | olafsvik
# Processing Record 44 of Set 7 | herne bay
# Processing Record 45 of Set 7 | kendari
# Processing Record 46 of Set 7 | lensk
# Processing Record 47 of Set 7 | haimen
# Processing Record 48 of Set 7 | meulaboh
# Processing Record 49 of Set 7 | kamenskoye
# City not Found
# Processing Record 50 of Set 7 | coquimbo
# Processing Record 1 of Set 8 | toora-khem
# Processing Record 2 of Set 8 | mayumba
# Processing Record 3 of Set 8 | lata
# Processing Record 4 of Set 8 | patuli
# Processing Record 5 of Set 8 | vaitupu
# City not Found
# Processing Record 6 of Set 8 | skibbereen
# Processing Record 7 of Set 8 | bobon
# Processing Record 8 of Set 8 | lethem
# Processing Record 9 of Set 8 | taoudenni
# Processing Record 10 of Set 8 | san vicente
# Processing Record 11 of Set 8 | fukue
# Processing Record 12 of Set 8 | tucurui
# Processing Record 13 of Set 8 | izmalkovo
# Processing Record 14 of Set 8 | castro
# Processing Record 15 of Set 8 | los corrales de buelna
# Processing Record 16 of Set 8 | hoopstad
# Processing Record 17 of Set 8 | shache
# Processing Record 18 of Set 8 | canitas
# City not Found
# Processing Record 19 of Set 8 | nabire
# Processing Record 20 of Set 8 | saint-leu
# Processing Record 21 of Set 8 | tuy hoa
# Processing Record 22 of Set 8 | port moresby
# Processing Record 23 of Set 8 | at-bashi
# Processing Record 24 of Set 8 | eten
# Processing Record 25 of Set 8 | harer
# Processing Record 26 of Set 8 | morros
# Processing Record 27 of Set 8 | belyy yar
# Processing Record 28 of Set 8 | rungata
# City not Found
# Processing Record 29 of Set 8 | punta umbria
# Processing Record 30 of Set 8 | petrinja
# Processing Record 31 of Set 8 | ulaangom
# Processing Record 32 of Set 8 | mandalgovi
# Processing Record 33 of Set 8 | rudbar
# Processing Record 34 of Set 8 | rolim de moura
# City not Found
# Processing Record 35 of Set 8 | mizque
# Processing Record 36 of Set 8 | laguna
# Processing Record 37 of Set 8 | evensk
# Processing Record 38 of Set 8 | thyolo
# Processing Record 39 of Set 8 | berlevag
# Processing Record 40 of Set 8 | charters towers
# Processing Record 41 of Set 8 | bubaque
# Processing Record 42 of Set 8 | westpunt
# City not Found
# Processing Record 43 of Set 8 | san patricio
# Processing Record 44 of Set 8 | agde
# Processing Record 45 of Set 8 | long branch
# Processing Record 46 of Set 8 | rabo de peixe
# Processing Record 47 of Set 8 | aden
# Processing Record 48 of Set 8 | botwood
# Processing Record 49 of Set 8 | nueve de julio
# Processing Record 50 of Set 8 | bonavista
# Processing Record 1 of Set 9 | aksarka
# Processing Record 2 of Set 9 | aswan
# Processing Record 3 of Set 9 | aksehir
# Processing Record 4 of Set 9 | sosnovo-ozerskoye
# Processing Record 5 of Set 9 | the valley
# Processing Record 6 of Set 9 | tabulbah
# City not Found
# Processing Record 7 of Set 9 | smithers
# Processing Record 8 of Set 9 | shaartuz
# City not Found
# Processing Record 9 of Set 9 | tabukiniberu
# City not Found
# Processing Record 10 of Set 9 | faridabad
# Processing Record 11 of Set 9 | bathsheba
# Processing Record 12 of Set 9 | maloy
# Processing Record 13 of Set 9 | ilulissat
# Processing Record 14 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 9 | talaya
# Processing Record 16 of Set 9 | baghmara
# Processing Record 17 of Set 9 | klaksvik
# Processing Record 18 of Set 9 | aykhal
# Processing Record 19 of Set 9 | grindavik
# Processing Record 20 of Set 9 | amancio
# City not Found
# Processing Record 21 of Set 9 | payson
# Processing Record 22 of Set 9 | haapiti
# Processing Record 23 of Set 9 | louisbourg
# City not Found
# Processing Record 24 of Set 9 | wulanhaote
# City not Found
# Processing Record 25 of Set 9 | satitoa
# City not Found
# Processing Record 26 of Set 9 | gloversville
# Processing Record 27 of Set 9 | tabory
# Processing Record 28 of Set 9 | atasu
# Processing Record 29 of Set 9 | godda
# Processing Record 30 of Set 9 | petilia policastro
# Processing Record 31 of Set 9 | issoire
# Processing Record 32 of Set 9 | pitsunda
# Processing Record 33 of Set 9 | mariental
# Processing Record 34 of Set 9 | cururupu
# Processing Record 35 of Set 9 | kolpny
# Processing Record 36 of Set 9 | bambanglipuro
# Processing Record 37 of Set 9 | kulhudhuffushi
# Processing Record 38 of Set 9 | vestmanna
# Processing Record 39 of Set 9 | yanan
# City not Found
# Processing Record 40 of Set 9 | husavik
# Processing Record 41 of Set 9 | viligili
# City not Found
# Processing Record 42 of Set 9 | port hardy
# Processing Record 43 of Set 9 | mujiayingzi
# Processing Record 44 of Set 9 | khingansk
# Processing Record 45 of Set 9 | aurdal
# Processing Record 46 of Set 9 | puerto escondido
# Processing Record 47 of Set 9 | tondano
# Processing Record 48 of Set 9 | jiehu
# Processing Record 49 of Set 9 | wuda
# Processing Record 50 of Set 9 | vaitape
# Processing Record 1 of Set 10 | aksu
# Processing Record 2 of Set 10 | lakatoro
# Processing Record 3 of Set 10 | marzuq
# Processing Record 4 of Set 10 | san rafael
# Processing Record 5 of Set 10 | camacha
# Processing Record 6 of Set 10 | lavrentiya
# Processing Record 7 of Set 10 | hvide sande
# Processing Record 8 of Set 10 | tilichiki
# Processing Record 9 of Set 10 | pontes e lacerda
# Processing Record 10 of Set 10 | tekeli
# Processing Record 11 of Set 10 | palmeira
# Processing Record 12 of Set 10 | pemba
# Processing Record 13 of Set 10 | anda
# Processing Record 14 of Set 10 | port elizabeth
# Processing Record 15 of Set 10 | oussouye
# Processing Record 16 of Set 10 | manzhouli
# Processing Record 17 of Set 10 | lithgow
# Processing Record 18 of Set 10 | edson
# Processing Record 19 of Set 10 | rawson
# Processing Record 20 of Set 10 | odweyne
# Processing Record 21 of Set 10 | minab
# Processing Record 22 of Set 10 | puchov
# Processing Record 23 of Set 10 | la rioja
# Processing Record 24 of Set 10 | nanjing
# Processing Record 25 of Set 10 | guerrero negro
# Processing Record 26 of Set 10 | sambava
# Processing Record 27 of Set 10 | jaisalmer
# Processing Record 28 of Set 10 | chinsali
# Processing Record 29 of Set 10 | turayf
# Processing Record 30 of Set 10 | piacabucu
# Processing Record 31 of Set 10 | fairbanks
# Processing Record 32 of Set 10 | catuday
# Processing Record 33 of Set 10 | half moon bay
# Processing Record 34 of Set 10 | englehart
# Processing Record 35 of Set 10 | mercedes
# Processing Record 36 of Set 10 | baft
# Processing Record 37 of Set 10 | srednekolymsk
# Processing Record 38 of Set 10 | zeya
# Processing Record 39 of Set 10 | maningrida
# Processing Record 40 of Set 10 | poum
# Processing Record 41 of Set 10 | batangafo
# Processing Record 42 of Set 10 | channel-port aux basques
# Processing Record 43 of Set 10 | armacao dos buzios
# City not Found
# Processing Record 44 of Set 10 | marilia
# Processing Record 45 of Set 10 | helena
# Processing Record 46 of Set 10 | belaya gora
# Processing Record 47 of Set 10 | tabou
# Processing Record 48 of Set 10 | raudeberg
# Processing Record 49 of Set 10 | fort nelson
# Processing Record 50 of Set 10 | seoul
# Processing Record 1 of Set 11 | guajara-mirim
# City not Found
# Processing Record 2 of Set 11 | nara
# Processing Record 3 of Set 11 | tranas
# Processing Record 4 of Set 11 | yerbogachen
# Processing Record 5 of Set 11 | det udom
# Processing Record 6 of Set 11 | laguna de duero
# Processing Record 7 of Set 11 | fairview
# Processing Record 8 of Set 11 | nalut
# Processing Record 9 of Set 11 | padre bernardo
# Processing Record 10 of Set 11 | porto velho
# Processing Record 11 of Set 11 | ossora
# Processing Record 12 of Set 11 | barbar
# City not Found
# Processing Record 13 of Set 11 | yuzhno-kurilsk
# Processing Record 14 of Set 11 | davidson
# Processing Record 15 of Set 11 | sheridan
# Processing Record 16 of Set 11 | urumqi
# Processing Record 17 of Set 11 | lasa
# Processing Record 18 of Set 11 | seymchan
# Processing Record 19 of Set 11 | pilar
# Processing Record 20 of Set 11 | maceio
# Processing Record 21 of Set 11 | gurskoye
# City not Found
# Processing Record 22 of Set 11 | port shepstone
# Processing Record 23 of Set 11 | viedma
# Processing Record 24 of Set 11 | rio gallegos
# Processing Record 25 of Set 11 | gudivada
# Processing Record 26 of Set 11 | zheleznodorozhnyy
# Processing Record 27 of Set 11 | la ronge
# Processing Record 28 of Set 11 | boyolangu
# Processing Record 29 of Set 11 | dahuk
# Processing Record 30 of Set 11 | nuuk
# Processing Record 31 of Set 11 | kiruna
# Processing Record 32 of Set 11 | alihe
# Processing Record 33 of Set 11 | puerto colombia
# Processing Record 34 of Set 11 | kilindoni
# Processing Record 35 of Set 11 | coari
# Processing Record 36 of Set 11 | ugoofaaru
# Processing Record 37 of Set 11 | ust-kamchatsk
# City not Found
# Processing Record 38 of Set 11 | north bend
# Processing Record 39 of Set 11 | nyimba
# Processing Record 40 of Set 11 | natal
# Processing Record 41 of Set 11 | taltal
# Processing Record 42 of Set 11 | samfya
# Processing Record 43 of Set 11 | avera
# Processing Record 44 of Set 11 | dingle
# Processing Record 45 of Set 11 | borogontsy
# Processing Record 46 of Set 11 | namibe
# Processing Record 47 of Set 11 | anaconda
# Processing Record 48 of Set 11 | alice springs
# Processing Record 49 of Set 11 | felix perez cardozo
# City not Found
# Processing Record 50 of Set 11 | mayo
# Processing Record 1 of Set 12 | tarko-sale
# Processing Record 2 of Set 12 | mega
# Processing Record 3 of Set 12 | coruripe
# Processing Record 4 of Set 12 | amderma
# City not Found
# Processing Record 5 of Set 12 | prince rupert
# Processing Record 6 of Set 12 | touba
# Processing Record 7 of Set 12 | impfondo
# Processing Record 8 of Set 12 | shingu
# Processing Record 9 of Set 12 | bilma
# Processing Record 10 of Set 12 | nakskov
# Processing Record 11 of Set 12 | broken hill
# Processing Record 12 of Set 12 | zunheboto
# Processing Record 13 of Set 12 | los llanos de aridane
# Processing Record 14 of Set 12 | eureka
# Processing Record 15 of Set 12 | kouroussa
# Processing Record 16 of Set 12 | asau
# Processing Record 17 of Set 12 | kiama
# Processing Record 18 of Set 12 | alta floresta
# Processing Record 19 of Set 12 | mnogovershinnyy
# Processing Record 20 of Set 12 | champerico
# Processing Record 21 of Set 12 | miguel auza
# Processing Record 22 of Set 12 | young
# Processing Record 23 of Set 12 | lins
# Processing Record 24 of Set 12 | portmore
# Processing Record 25 of Set 12 | kahului
# Processing Record 26 of Set 12 | lungi
# Processing Record 27 of Set 12 | sechura
# Processing Record 28 of Set 12 | chico
# Processing Record 29 of Set 12 | batagay
# Processing Record 30 of Set 12 | kitimat
# Processing Record 31 of Set 12 | wichita
# Processing Record 32 of Set 12 | vuktyl
# Processing Record 33 of Set 12 | ghanzi
# Processing Record 34 of Set 12 | ostrovnoy
# Processing Record 35 of Set 12 | adre
# Processing Record 36 of Set 12 | bunia
# Processing Record 37 of Set 12 | damietta
# Processing Record 38 of Set 12 | hangzhou
# Processing Record 39 of Set 12 | gagret
# Processing Record 40 of Set 12 | thinadhoo
# Processing Record 41 of Set 12 | geraldton
# Processing Record 42 of Set 12 | samalaeulu
# City not Found
# Processing Record 43 of Set 12 | tadine
# Processing Record 44 of Set 12 | kuche
# City not Found
# Processing Record 45 of Set 12 | tezu
# Processing Record 46 of Set 12 | altay
# Processing Record 47 of Set 12 | myitkyina
# Processing Record 48 of Set 12 | shimoda
# Processing Record 49 of Set 12 | mitsamiouli
# Processing Record 50 of Set 12 | warqla
# City not Found
# Processing Record 1 of Set 13 | oga
# Processing Record 2 of Set 13 | saint-francois
# Processing Record 3 of Set 13 | kharan
# Processing Record 4 of Set 13 | mekhe
# Processing Record 5 of Set 13 | tunceli
# Processing Record 6 of Set 13 | itoman
# Processing Record 7 of Set 13 | eina
# Processing Record 8 of Set 13 | kenai
# Processing Record 9 of Set 13 | puerto madero
# Processing Record 10 of Set 13 | huarmey
# Processing Record 11 of Set 13 | lorengau
# Processing Record 12 of Set 13 | mentok
# City not Found
# Processing Record 13 of Set 13 | paamiut
# Processing Record 14 of Set 13 | chabahar
# Processing Record 15 of Set 13 | timmins
# Processing Record 16 of Set 13 | oxford
# Processing Record 17 of Set 13 | tete
# Processing Record 18 of Set 13 | salekhard
# Processing Record 19 of Set 13 | bila krynytsya
# Processing Record 20 of Set 13 | jiazi
# Processing Record 21 of Set 13 | margate
# Processing Record 22 of Set 13 | caxito
# Processing Record 23 of Set 13 | xaltianguis
# Processing Record 24 of Set 13 | salima
# Processing Record 25 of Set 13 | jumla
# Processing Record 26 of Set 13 | dunedin
# Processing Record 27 of Set 13 | moyobamba
# Processing Record 28 of Set 13 | takoradi
# Processing Record 29 of Set 13 | zamora
# Processing Record 30 of Set 13 | george town
# Processing Record 31 of Set 13 | portland
# Processing Record 32 of Set 13 | galesong
# Processing Record 33 of Set 13 | banjar
# Processing Record 34 of Set 13 | freeport
# Processing Record 35 of Set 13 | obama
# Processing Record 36 of Set 13 | chontalpa
# Processing Record 37 of Set 13 | noumea
# Processing Record 38 of Set 13 | oistins
# Processing Record 39 of Set 13 | cayenne
# Processing Record 40 of Set 13 | chokwe
# Processing Record 41 of Set 13 | najran
# Processing Record 42 of Set 13 | campbeltown
# Processing Record 43 of Set 13 | birao
# Processing Record 44 of Set 13 | naze
# Processing Record 45 of Set 13 | suzhou
# Processing Record 46 of Set 13 | wajima
# Processing Record 47 of Set 13 | srandakan
# Processing Record 48 of Set 13 | muros
# Processing Record 49 of Set 13 | quang ngai
# Processing Record 50 of Set 13 | san andres
# Processing Record 1 of Set 14 | kutum
# Processing Record 2 of Set 14 | port-gentil
# Processing Record 3 of Set 14 | monte plata
# Processing Record 4 of Set 14 | daxian
# City not Found
# Processing Record 5 of Set 14 | montigny-le-bretonneux
# Processing Record 6 of Set 14 | dafeng
# Processing Record 7 of Set 14 | socorro
# Processing Record 8 of Set 14 | yarmouth
# Processing Record 9 of Set 14 | biltine
# Processing Record 10 of Set 14 | saint-cyr-sur-loire
# Processing Record 11 of Set 14 | kyzyl-suu
# Processing Record 12 of Set 14 | luanda
# Processing Record 13 of Set 14 | muswellbrook
# Processing Record 14 of Set 14 | saint-pierre
# Processing Record 15 of Set 14 | marsa matruh
# Processing Record 16 of Set 14 | rawannawi
# City not Found
# Processing Record 17 of Set 14 | extremoz
# Processing Record 18 of Set 14 | palu
# Processing Record 19 of Set 14 | waipawa
# Processing Record 20 of Set 14 | farah
# Processing Record 21 of Set 14 | samarai
# Processing Record 22 of Set 14 | wamba
# Processing Record 23 of Set 14 | diego de almagro
# Processing Record 24 of Set 14 | moranbah
# Processing Record 25 of Set 14 | domna
# Processing Record 26 of Set 14 | mizdah
# Processing Record 27 of Set 14 | monrovia
# Processing Record 28 of Set 14 | karlskrona
# Processing Record 29 of Set 14 | gunjur
# Processing Record 30 of Set 14 | botro
# Processing Record 31 of Set 14 | vila
# Processing Record 32 of Set 14 | talcahuano
# Processing Record 33 of Set 14 | yarada
# Processing Record 34 of Set 14 | bandarbeyla
# Processing Record 35 of Set 14 | tandil
# Processing Record 36 of Set 14 | fukuma
# Processing Record 37 of Set 14 | cidreira
# Processing Record 38 of Set 14 | konotop
# Processing Record 39 of Set 14 | arua
# Processing Record 40 of Set 14 | tahe
# Processing Record 41 of Set 14 | salinas
# Processing Record 42 of Set 14 | camapua
# Processing Record 43 of Set 14 | hualmay
# Processing Record 44 of Set 14 | saint-georges
# Processing Record 45 of Set 14 | vryburg
# Processing Record 46 of Set 14 | roald
# Processing Record 47 of Set 14 | marrakesh
# Processing Record 48 of Set 14 | batemans bay
# Processing Record 49 of Set 14 | jiaozuo
# Processing Record 50 of Set 14 | wanning
# Processing Record 1 of Set 15 | parrita
# Processing Record 2 of Set 15 | sitka
# Processing Record 3 of Set 15 | mustasaari
# Processing Record 4 of Set 15 | yenagoa
# Processing Record 5 of Set 15 | burriana
# Processing Record 6 of Set 15 | guiyang
# Processing Record 7 of Set 15 | general pico
# Processing Record 8 of Set 15 | palabuhanratu
# City not Found
# Processing Record 9 of Set 15 | puerto carreno
# Processing Record 10 of Set 15 | kurtamysh
# Processing Record 11 of Set 15 | longlac
# City not Found
# Processing Record 12 of Set 15 | ascope
# Processing Record 13 of Set 15 | ambikapur
# Processing Record 14 of Set 15 | bowen
# Processing Record 15 of Set 15 | balimo
# City not Found
# Processing Record 16 of Set 15 | ambilobe
# Processing Record 17 of Set 15 | kununurra
# Processing Record 18 of Set 15 | digby
# Processing Record 19 of Set 15 | waddan
# Processing Record 20 of Set 15 | kushima
# Processing Record 21 of Set 15 | mozarlandia
# Processing Record 22 of Set 15 | uige
# Processing Record 23 of Set 15 | ritchie
# Processing Record 24 of Set 15 | mulege
# Processing Record 25 of Set 15 | luena
# Processing Record 26 of Set 15 | pringsewu
# Processing Record 27 of Set 15 | bocas del toro
# Processing Record 28 of Set 15 | ossipee
# Processing Record 29 of Set 15 | bajil
# Processing Record 30 of Set 15 | alcudia

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Souillac -20.52   57.52     69.80        68          40        9.17
# 1            Kovur  14.48   79.98     76.17        76          48        3.98
# 2           Atuona  -9.80 -139.03     77.47        79          68       15.12
# 3           Bethel  41.37  -73.41     52.00        93          90        4.70
# 4        Upernavik  72.79  -56.15     15.85        92          97        3.89
# 5        Busselton -33.65  115.33     57.99        77          84        5.48
# 6       Butaritari   3.07  172.79     82.29        78           6       10.33
# 7            Pisco -13.70  -76.22     64.40        82          90       13.87
# 8  Arraial Do Cabo -22.97  -42.03     71.60        64          75       14.99
# 9            Luohe  33.57  114.04     54.54        40          50        5.23
#
#   Country Current Description
# 0      MU    scattered clouds
# 1      IN    scattered clouds
# 2      PF          light rain
# 3      US                mist
# 4      GL     overcast clouds
# 5      AU       broken clouds
# 6      KI           clear sky
# 7      PE     overcast clouds
# 8      BR       broken clouds
# 9      CN    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
