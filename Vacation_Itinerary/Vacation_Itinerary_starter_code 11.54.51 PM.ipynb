# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
hotel_name = vacation_df["Hotel Name"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
preferred_city = vacation_df[vacation_df['Country'] == "US"]
preferred_city
#preferred_city.columns
# Out:
#      City_ID              City Country  Max Temp Current Description    Lat  \
# 16        38       Punta Gorda      US     81.00     overcast clouds  26.93
# 18        45              Hilo      US     86.00    scattered clouds  19.73
# 28        74       Tallahassee      US     77.00          few clouds  30.44
# 39       112     Makakilo City      US     84.20     overcast clouds  21.35
# 48       144          San Jose      US     84.00                haze  37.34
# 60       167      Saint George      US     81.00           clear sky  37.10
# 63       174         Galveston      US     75.20           clear sky  29.37
# 64       180            Lompoc      US     79.00           clear sky  34.64
# 78       225             Kapaa      US     82.40          few clouds  22.08
# 82       234       San Joaquin      US     80.60           clear sky  37.93
# 96       285  Saint Pete Beach      US     80.60           clear sky  27.73
# 118      351            Laguna      US     82.00           clear sky  38.42
# 121      357      San Patricio      US     80.60          few clouds  28.02
# 127      381            Payson      US     71.01           clear sky  40.04
# 147      438     Half Moon Bay      US     78.01           clear sky  37.46
# 179      523           Kahului      US     89.60    scattered clouds  20.89
# 181      526             Chico      US     84.00           clear sky  39.73
# 207      600           Socorro      US     71.60          few clouds  31.65
#
#         Lng                                         Hotel Name
# 16   -82.05     Four Points by Sheraton Punta Gorda Harborside
# 18  -155.09                                Hilo Hawaiian Hotel
# 28   -84.28       Four Points by Sheraton Tallahassee Downtown
# 39  -158.09                     Marriott's Ko Olina Beach Club
# 48  -121.89                                The Westin San Jose
# 60  -113.58                        Best Western Plus Abbey Inn
# 63   -94.97                    Comfort Inn & Suites Texas City
# 64  -120.46                         Holiday Inn Express Lompoc
# 78  -159.32             Sheraton Kauai Resort at Coconut Beach
# 82  -121.30                  University Plaza Waterfront Hotel
# 96   -82.74                     TradeWinds Island Grand Resort
# 118 -121.42  Holiday Inn Express & Suites Elk Grove Central...
# 121  -97.52                                 Motel 6 Sinton, TX
# 127 -111.73                            Quality Inn Payson I-15
# 147 -122.43                    The Ritz-Carlton, Half Moon Bay
# 179 -156.47                                 Maui Seaside Hotel
# 181 -121.84                       Quality Inn Near Chico State
# 207 -106.30                            guarderia imss papalote

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df['City'] == 'Tallahassee']
vacation_end = vacation_df.loc[vacation_df['City'] == 'Tallahassee']
vacation_stop1 = vacation_df.loc[vacation_df['City'] == 'Saint Pete Beach']
vacation_stop2 = vacation_df.loc[vacation_df['City'] == 'Galveston']
vacation_stop3 = vacation_df.loc[vacation_df['City'] == 'Laguna']

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = (30.44,-84.28)
end = (30.44,-84.28)
stop1 = (27.73,-82.74)
stop2 = (29.37,-94.97)
stop3 = (38.42,-121.42)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure()
travel = gmaps.directions_layer(start, end, waypoints=[stop1, stop2, stop3],
                                travel_mode='DRIVING')
fig.add_layer(travel)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_end, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID              City Country  Max Temp Current Description    Lat  \
# 0       74       Tallahassee      US      77.0          few clouds  30.44
# 1       74       Tallahassee      US      77.0          few clouds  30.44
# 2      285  Saint Pete Beach      US      80.6           clear sky  27.73
# 3      174         Galveston      US      75.2           clear sky  29.37
# 4      351            Laguna      US      82.0           clear sky  38.42
#
#       Lng                                         Hotel Name
# 0  -84.28       Four Points by Sheraton Tallahassee Downtown
# 1  -84.28       Four Points by Sheraton Tallahassee Downtown
# 2  -82.74                     TradeWinds Island Grand Resort
# 3  -94.97                    Comfort Inn & Suites Texas City
# 4 -121.42  Holiday Inn Express & Suites Elk Grove Central...

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
hotel_name = itinerary_df["Hotel Name"]
fig = gmaps.figure(center=(30.0, -90), zoom_level=3.0)
travel = gmaps.directions_layer(start, end, waypoints=[stop1, stop2, stop3],
                                travel_mode='DRIVING')

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)
fig.add_layer(travel)


# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
